# %%
 # Python Practice

# %%
'Hello World'
# Out:
# 'Hello World'

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
a = 3

# %%
a
# Out:
# 3

# %%
b = "Hello World"

# %%
b
# Out:
# 'Hello World'

# %%
age = 30
print("I am {x} years old".format(x = age))
# Out:
# I am 30 years old

# %%
name = input()
print(name)
# Out:
#  Santosh
# Santosh

# %%
print(name)
# Out:
# Santosh

# %%
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name:  Santosh
# Santosh

# %%
clecius = float(input("Enter the temperature in degree Celcius:"))
Faraniend = (clecius*9/5)+ 32
print("Faraniend: ", Faraniend)
# Out:
# Enter the temperature in degree Celcius: 98
# Faraniend:  208.4

# %%
balance = 1000.0
deposit = input('Enter the deposit amount:' )
withdraw = input('Enter the withdrar amount:' )
balance = balance - float(withdraw) + float(deposit)
print("Balance is: ", balance)
# Out:
# Enter the deposit amount: 0
# Enter the withdrar amount: 100
# Balance is:  900.0

# %%
loginStatus = input('Is the uswr logged in:')
subscriptionStatus = input('Is the uswr Subscripbed in:')
if(subscriptionStatus== 'Yes' and loginStatus == 'Yes'):
    print('User can premium access')
else:
    print('User cannot premium access')
