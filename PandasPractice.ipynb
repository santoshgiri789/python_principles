# %%
# Pandas is powerful and useful library used for data analyis
import pandas as pd
nba_df = pd.read_csv('nba.csv')
print(nba_df.head()) # Top 5 rows
print(nba_df.tail()) # Last 5 rows
print('Rows and Colns',nba_df.shape)
print('Data Type',nba_df.dtypes)
print('Describe',nba_df.describe())
print('Name')
print(nba_df.Name.head())
print('Multiple columns')
print(nba_df[['Name', 'Team', 'Salary']].head())
nba_df[ (nba_df.Team == 'Boston Celtics') & (nba_df.Age <= 25) ]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# ...

# %%
nba_df.sort_values(by = 'Weight', ascending = False)
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 405    Nikola Pekovic  Minnesota Timberwolves    14.0        C  30.0   6-11
# 302  Boban Marjanovic       San Antonio Spurs    40.0        C  27.0    7-3
# 330      Al Jefferson       Charlotte Hornets    25.0        C  31.0   6-10
# 395      Jusuf Nurkic          Denver Nuggets    23.0        C  21.0    7-0
# 188    Andre Drummond         Detroit Pistons     0.0        C  22.0   6-11
# ..                ...                     ...     ...      ...   ...    ...
# 359  Brandon Jennings           Orlando Magic    55.0       PG  26.0    6-1
# 263      Bryce Cotton       Memphis Grizzlies     8.0       PG  23.0    6-1
# 350     Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 152      Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 457               NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College      Salary
# ...

# %%
nba_df[ (nba_df.Team == 'Memphis Grizzlies') & (nba_df.Position == 'PG')].sort_values(by='Salary', ascending = False).head(1)
# Out:
#             Name               Team  Number Position   Age Height  Weight  \
# 262  Mike Conley  Memphis Grizzlies    11.0       PG  28.0    6-1   175.0
#
#         College     Salary
# 262  Ohio State  9588426.0
