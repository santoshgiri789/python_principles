# %% [markdown]
# # String manipulation
# # Exposure to various string functions

# %%
msg = 'CroCodIle'

# %%
msg.lower()
# Out:
# 'crocodile'

# %%
msg[0]
# Out:
# 'C'

# %%
msg[-1]
# Out:
# 'e'

# %%
msg.upper()
# Out:
# 'CROCODILE'

# %%
print(msg.index('o'))
# Out:
# 2

# %%
"CroCodIle".title()
# Out:
# 'Crocodile'

# %%
price ="2 1"

# %%
price.isdigit()
# Out:
# False

# %%
price ="21"

# %%
price.isdigit()
# Out:
# True

# %%
garbage = 'macbook,iphone,airpods-marigold-ipad,s25'

# %%
mylist1 = garbage.split(',')

# %%
mylist1
# Out:
# ['macbook', ' iphone', ' airpods-marigold-ipad', 's25']

# %%
data=mylist1[2].strip()

# %%
data
# Out:
# 'airpods-marigold-ipad'

# %%
marigold = data.split('-')

# %%
marigold[1]
# Out:
# 'marigold'

# %%
placementData = "JPMorgan 650 STATESTREET 250 L_&_t 200"

# %%
data = placementData.split(' ')

# %%
data
# Out:
# ['JPMorgan', '650', 'STATESTREET', '250', 'L_&_t', '200']

# %%
for dataEle in data:
    print(dataEle, dataEle.isdigit())
# Out:
# JPMorgan False
# 650 True
# STATESTREET False
# 250 True
# L_&_t False
# 200 True

# %%
scores = []
for dataEle in data:
    if dataEle.isdigit():
        print(dataEle, dataEle.isdigit())
        scores.append(int(dataEle))
print("List:",scores)
print("Total:", sum(scores))
avg = sum(scores) / len(scores)
print("Avg:", avg)
# Out:
# 650 True
# 250 True
# 200 True
# List: [650, 250, 200]
# Total: 1100
# Avg: 366.6666666666667

# %%
# Key =empName, Value = contact
contacts['']

# %%
long_words = [
    "pneumonoultramicroscopicsilicovolcanoconiosis",
    "hippopotomonstrosesquippedaliophobia",
    "supercalifragilisticexpialidocious",
    "pseudopsychotherapeutic"
]
disc = {}
for word in long_words:
    disc[word] = len(word)
print(disc)
# Out:
# {'pneumonoultramicroscopicsilicovolcanoconiosis': 45, 'hippopotomonstrosesquippedaliophobia': 36, 'supercalifragilisticexpialidocious': 34, 'pseudopsychotherapeutic': 23}

# %%
# Sample list of 10 Cibil scores
def evaluateResult(score):
    result = {}
    for score in cibil_scores:
        if score > 750:
            result[score] = 'Approved'
        elif score > 650:
            result[score] = 'Review'
        elif score > 550:
            result[score] = 'Risky'
        elif score < 550:
            result[score] = 'Rejected'
    return result
    
cibil_scores = [785,420,670,590,810,545,660,715,300,580]
reultReturned = evaluateResult(cibil_scores)

print(reultReturned)
# Out:
# {785: 'Approved', 420: 'Rejected', 670: 'Review', 590: 'Risky', 810: 'Approved', 545: 'Rejected', 660: 'Review', 715: 'Review', 300: 'Rejected', 580: 'Risky'}
